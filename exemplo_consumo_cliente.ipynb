# %%
from core.ckan_api_reader import Ckan
from config import CKAN_DOMAIN

# %% [markdown]
# ## Instanciando o cliente
#
# O cliente requer um domínio de CKAN. Esse domínio está no arquivo .env.example
#
# Para você conseguir rodar local, apenas dê um "cp .env.example .env" em sua máquina que ele configura certinho para o CKAN do Seade.

# %%
ckan = Ckan(CKAN_DOMAIN)

# %%
ckan.pkgs
# Out:
# {'agricultura-municipal',
#  'anexo-metodologico-populacao',
#  'anexos-metodologicos-seade-municipios',
#  'aprovacao-escolar-por-municipio-ano-nivel-de-ensino-e-rede-de-atendimento',
#  'casamentos',
#  'cnae-20',
#  'codigos-nomes-dos-distritos-do-municipio-de-sao-paulo',
#  'comercio-exterior',
#  'comercio-exterior-nos-municipios',
#  'covid-19',
#  'demografia',
#  'domicilios-estado-de-sao-paulo',
#  'economia',
#  'educacao-basica-painel',
#  'educacao-do-ensino-superior',
#  'emprego-formal-2021-painel',
#  'emprego-formal-ocupacoes',
#  'emprego-rais-e-arquivos-auxiliares',
#  'equipamento',
#  'estabelecimentos-de-saude',
#  'estatisticas-vitais',
#  'estatisticas-vitais-microdados',
#  'ideb',
#  'indice-paulista-de-desenvolvimento-municipal-ipdm',
#  'informacoes-municipais',
#  'infraestrutura-e-meio-ambiente',
#  'leitos-hospitalares-por-municipio-por-ano',
#  'limites-e-regioes',
#  'matriculas-por-municipio-ano-nivel-de-ensino-e-rede-de-atendimento',
#  'medicos-e-enfermeiros-por-municipio-ano-e-rede-de-atendimento',
#  'microdados-casamentos',
#  'microdados-nascidos-vivos',
#  'microdados-obitos',
#  'mortalidade-infantil',
#  'mortalidade-no-estado-de-sao-paulo',
#  'municipios',
#  'nascidos-vivos',
#  'nascidos-vivos-municipio-de-sao-paulo',
#  'nomes-codigos-municipios-esp',
#  'obitos',
#  'obitos-municipio-de-sao-paulo',
#  'ocupacao-e-rendimento',
#  'painel-economia-agropecuaria',
#  'pecuaria-municipal',
#  'pesquisa-de-cuidados-no-domicilio',
#  'pib-anual-2002-2020',
#  'pib-mensal',
#  'pib-municipal-2002-2020',
#  'pib-regional',
#  'pib-trimestral',
#  'populacao-do-municipio-de-sao-paulo-por-distrito-e-idade-escolar',
#  'populacao-do-municipio-de-sao-paulo-por-distrito-e-porte-populacional',
#  'populacao-do-municipio-de-sp-por-distritos',
#  'populacao-municipal-2010-2022',
#  'populacao-municipal-por-sexo-e-idade-2010-2021',
#  'populacao-por-municipio-de-idade-escolar',
#  'populacao-residente-estado-de-sao-paulo',
#  'populacao-residente-estado-de-sao-paulo-evolucao',
#  'populacao-residente-municipio-de-sao-paulo',
#  'populacao-residente-municipio-de-sao-paulo-evolucao',
#  'populacao-total-2021-e-idadessimples',
#  'populacao-urbana-e-rural',
#  'projecao-da-populacao-do-estado-de-sao-paulo-por-idade-2021',
#  'projecao-da-populacao-por-municipio-idade-escolar-sexo-e-ano',
#  'projecao-da-populacao-por-municipio-idade-sexo-e-ano-2010-2021',
#  'saneamento-estado-de-sao-paulo-e-brasil',
#  'saude-painel',
#  'seade-censo-2022',
#  'seade-fecundidade',
#  'seade-industria',
#  'seade-investimentos',
#  'seade-investimentos-anexos-metodologicos',
#  'seade-painel',
#  'seade-trajetorias-ocupacionais',
#  'social',
#  'trajetorias-ocupacionais-anexos-metodologicos',
#  'transferencia-de-renda-painel',
#  'valor-de-transformacao-industrial-nos-municipios'}

# %%
res = ckan('social', search_string='Tipologia', attr='name', how='contains', as_list=True)[0]

# %%
res
# Out:
# {'cache_last_updated': None,
#  'cache_url': None,
#  'created': '2023-01-19T23:46:05.573918',
#  'datastore_active': False,
#  'description': 'Tipologia intraurbana por área de ponderação, 2017',
#  'format': 'ZIP',
#  'hash': '',
#  'id': '60659f8e-df7d-44d9-aaeb-fb6ab4f6c7b5',
#  'last_modified': '2023-01-19T23:46:05.553465',
#  'metadata_modified': '2023-01-19T23:46:07.578812',
#  'mimetype': 'application/zip',
#  'mimetype_inner': None,
#  'name': 'Tipologia Intraurbana',
#  'package_id': '2be01068-49cc-4cc1-85b8-38bd867aefc4',
#  'position': 7,
#  'resource_type': None,
#  'size': 5094207,
#  'state': 'active',
#  'url': 'https://repositorio.seade.gov.br/dataset/2be01068-49cc-4cc1-85b8-38bd867aefc4/resource/60659f8e-df7d-44d9-aaeb-fb6ab4f6c7b5/download/tipologia_intraurbana.zip',
#  'url_type': 'upload'}

# %%
with open('arquivo.xlsx', 'wb') as f:
    f.write(ckan.download_resource(res))

# %%
gen = ckan('social', extract=True, parser_params = {'skiprows' : 1})

# %%
next(gen)
# Out:
#      Grupo           Subgrupo  \
# 0   Social  Condições de Vida
# 1      NaN                NaN
# 2      NaN                NaN
# 3      NaN                NaN
# 4      NaN                NaN
# 5      NaN                NaN
# 6      NaN                NaN
# 7      NaN                NaN
# 8      NaN                NaN
# 9      NaN                NaN
# 10     NaN           Trabalho
# 11     NaN                NaN
# 12     NaN                NaN
# 13     NaN                NaN
# 14     NaN                NaN
# 15     NaN                NaN
# 16     NaN                NaN
# 17     NaN                NaN
# 18     NaN                NaN
# 19     NaN                NaN
# 20     NaN                NaN
# 21     NaN                NaN
# 22     NaN                NaN
# 23     NaN                NaN
# 24     NaN                NaN
# 25     NaN                NaN
# 26     NaN                NaN
# 27     NaN                NaN
# 28     NaN                NaN
# 29     NaN                NaN
#
#                                        Nome da camada  \
# 0    Índice Paulista de Vulnerabilidade Social (IPVS)
# 1   Índice de Desenvolvimento Humano Municipal (IDHM)
# 2                                                IPDM
# 3   Índice Paulista de Desenvolvimento Municipal (...
# 4   Índice Paulista de Desenvolvimento Municipal (...
# 5   Índice Paulista de Desenvolvimento Municipal (...
# 6   Índice Paulista de Desenvolvimento Municipal (...
# 7                               Tipologia Intraurbana
# 8                               Tipologia Intraurbana
# 9                               Concentrações Urbanas
# 10  Participação dos Empregos Formais em Relação a...
# 11  Participação do Emprego Formal Total em Relaçã...
# 12  Agricultura, Pecuária, Produção Florestal, Pes...
# 13  Construção - Participação em Relação ao Estado...
# 14  Indústria - Participação em Relação ao Estado ...
# 15  Comércio - Participação em Relação ao Estado  ...
# 16  Serviços  - Participação em Relação ao Estado ...
# 17  Participação dos Empregos Formais em Relação a...
# 18  Agricultura, Pecuária, Produção Florestal, Pes...
# 19  Construção - Participação em Relação ao Municí...
# 20  Indústria - Participação em Relação ao Municíp...
# 21  Comércio - Participação em Relação ao Municípi...
# 22  Serviços  - Participação em Relação ao Municíp...
# 23         Salário Médio Nominal dos Empregos Formais
# 24  Salário Médio Nominal do Total (em reais corre...
# 25  Salário Médio Nominal na Agricultura, Pecuária...
# 26  Salário Médio Nominal na Indústria (em reais c...
# 27  Salário Médio Nominal na Construção (em reais ...
# 28  Salário Médio Nominal no Comércio (em reais co...
# 29  Salário Médio Nominal nos Serviços (em reais c...
#
#                                                Resumo    Escala  \
# 0   O Índice Paulista de Vulnerabilidade Social (I...  1:50.000
# 1   O Índice de Desenvolvimento Humano é uma medid...  1:50.000
# 2                                                 NaN       NaN
# 3   O IPDM tem como objetivo oferecer um indicador...  1:50.000
# 4   O IPDM tem como objetivo oferecer um indicador...  1:50.000
# 5   O IPDM tem como objetivo oferecer um indicador...  1:50.000
# 6   O IPDM tem como objetivo oferecer um indicador...  1:50.000
# 7                                                 NaN       NaN
# 8   TIPOS INTRAURBANOS\nOs Tipos Intraurbanos são ...   1:5.000
# 9   As concentrações urbanas são definidas como Mu...   1:5.000
# 10                                                NaN       NaN
# 11  Compreende a proporção de empregos formais no ...  1:50.000
# 12  Compreende a proporção de empregos formais da ...  1:50.000
# 13  Compreende a proporção de empregos formais da ...  1:50.000
# 14  Compreende a proporção de empregos formais dos...  1:50.000
# 15  Compreende a proporção de empregos formais dos...  1:50.000
# 16  Compreende a proporção de empregos formais dos...  1:50.000
# 17                                                NaN       NaN
# 18  Compreende a proporção de empregos formais da ...  1:50.000
# 19  Compreende a proporção de empregos formais da ...  1:50.000
# 20  Compreende a proporção de empregos formais da ...  1:50.000
# 21  Compreende a proporção de empregos formais do ...  1:50.000
# 22  Compreende a proporção de empregos formais dos...  1:50.000
# 23                                                NaN       NaN
# 24  Soma dos rendimentos individuais em dezembro d...  1:50.000
# 25  Soma dos rendimentos individuais em dezembro d...  1:50.000
# 26  Soma dos rendimentos individuais em dezembro d...  1:50.000
# 27  Soma dos rendimentos individuais em dezembro d...  1:50.000
# 28  Soma dos rendimentos individuais em dezembro d...  1:50.000
# 29  Soma dos rendimentos individuais em dezembro d...  1:50.000
#
#     Data de referência                                        Responsável  \
# 0               2010.0  Assembléia Legislátiva do Estado de São Paulo/...
# 1               2010.0  Programa das Nações Unidas para o Desenvolvime...
# 2                  NaN                                                NaN
# 3               2021.0  Fundação Sistema Estadual de Análise de Dados ...
# 4               2021.0  Fundação Sistema Estadual de Análise de Dados ...
# 5               2021.0  Fundação Sistema Estadual de Análise de Dados ...
# 6               2021.0  Fundação Sistema Estadual de Análise de Dados ...
# 7                  NaN                                                NaN
# 8               2017.0  Intituto Brasileiro de Geografia e Estatítica ...
# 9               2017.0  Intituto Brasileiro de Geografia e Estatítica ...
# 10                 NaN                                                NaN
# 11              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 12              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 13              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 14              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 15              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 16              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 17                 NaN                                                NaN
# 18              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 19              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 20              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 21              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 22              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 23                 NaN                                                NaN
# 24              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 25              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 26              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 27              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 28              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
# 29              2021.0  Ministério do Trabalho e Emprego – MTE. Relaçã...
#
#    Sistema de Coordenadas, datum e EPSG Periodicidade de atualização
# 0                  SCG/SIRGAS 2000/4674                      Decenal
# 1                  SCG/SIRGAS 2000/4674                      Decenal
# 2                                   NaN                          NaN
# 3                  SCG/SIRGAS 2000/4674                  Sob demanda
# 4                  SCG/SIRGAS 2000/4674                  Sob demanda
# 5                  SCG/SIRGAS 2000/4674                  Sob demanda
# 6                  SCG/SIRGAS 2000/4674                  Sob demanda
# 7                                   NaN                          NaN
# 8                  SCG/SIRGAS 2000/4674                  Sob demanda
# 9                  SCG/SIRGAS 2000/4674                  Sob demanda
# 10                                  NaN                          NaN
# 11                 SCG/SIRGAS 2000/4674                        Anual
# 12                 SCG/SIRGAS 2000/4674                        Anual
# 13                 SCG/SIRGAS 2000/4674                        Anual
# 14                 SCG/SIRGAS 2000/4674                        Anual
# 15                 SCG/SIRGAS 2000/4674                        Anual
# 16                 SCG/SIRGAS 2000/4674                        Anual
# 17                                  NaN                          NaN
# 18                 SCG/SIRGAS 2000/4674                        Anual
# 19                 SCG/SIRGAS 2000/4674                        Anual
# 20                 SCG/SIRGAS 2000/4674                        Anual
# 21                 SCG/SIRGAS 2000/4674                        Anual
# 22                 SCG/SIRGAS 2000/4674                        Anual
# 23                                  NaN                          NaN
# 24                 SCG/SIRGAS 2000/4674                        Anual
# 25                 SCG/SIRGAS 2000/4674                        Anual
# 26                 SCG/SIRGAS 2000/4674                        Anual
# 27                 SCG/SIRGAS 2000/4674                        Anual
# 28                 SCG/SIRGAS 2000/4674                        Anual
# 29                 SCG/SIRGAS 2000/4674                        Anual
