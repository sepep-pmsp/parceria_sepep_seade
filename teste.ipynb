# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from components.map import Map

# %%
e = Map()

# %%
e.df_casamentos
# Out:
#     nome_municipio_destino  lon_destino  lat_destino   origem  destino  \
# 0               Adamantina   -51.056770   -21.576642  3550308  3500105
# 1                   Adolfo   -49.653287   -21.288679  3550308  3500204
# 2                    Aguaí   -47.040347   -22.049973  3550308  3500303
# 3           Águas da Prata   -46.691691   -21.913694  3550308  3500402
# 4         Águas de Lindóia   -46.603671   -22.474823  3550308  3500501
# ..                     ...          ...          ...      ...      ...
# 569              Viradouro   -48.309865   -20.884382  3550308  3556800
# 570   Vista Alegre do Alto   -48.649424   -21.176701  3550308  3556909
# 571             Votorantim   -47.406532   -23.579878  3550308  3557006
# 572            Votuporanga   -49.989102   -20.457810  3550308  3557105
# 573              Chavantes   -49.726537   -23.046320  3550308  3557204
#
#      total_casamentos   ano  lon_origem  lat_origem
# 0                  30  2021  -46.648013   -23.64992
# ...
