# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from etls.scripts.municipios.load import Load

# %%
e = Load()

# %%
e()
# Out:
#        cod_municipio nome_municipio  \
# 0            3500105     Adamantina
# 1            3500105     Adamantina
# 2            3500105     Adamantina
# 3            3500105     Adamantina
# 4            3500105     Adamantina
# ...              ...            ...
# 14185        3557303   Estiva Gerbi
# 14186        3557303   Estiva Gerbi
# 14187        3557303   Estiva Gerbi
# 14188        3557303   Estiva Gerbi
# 14189        3557303   Estiva Gerbi
#
#                               regiao_administrativa  \
# 0      Região Administrativa de Presidente Prudente
# 1      Região Administrativa de Presidente Prudente
# 2      Região Administrativa de Presidente Prudente
# 3      Região Administrativa de Presidente Prudente
# 4      Região Administrativa de Presidente Prudente
# ...                                             ...
# 14185             Região Administrativa de Campinas
# 14186             Região Administrativa de Campinas
# ...
