# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from etls.scripts.municipios.load import Load

# %%
e = Load()

# %%
e()
# Out:
#        cod_municipio  Nascidos vivos nome_municipio  \
# 0            3500105           131.0     Adamantina
# 1            3500105           131.0     Adamantina
# 2            3500105           131.0     Adamantina
# 3            3500105           131.0     Adamantina
# 4            3500105           131.0     Adamantina
# ...              ...             ...            ...
# 12250        3557303            53.0   Estiva Gerbi
# 12251        3557303            53.0   Estiva Gerbi
# 12252        3557303            53.0   Estiva Gerbi
# 12253        3557303            53.0   Estiva Gerbi
# 12254        3557303            53.0   Estiva Gerbi
#
#                               regiao_administrativa  \
# 0      Região Administrativa de Presidente Prudente
# 1      Região Administrativa de Presidente Prudente
# 2      Região Administrativa de Presidente Prudente
# 3      Região Administrativa de Presidente Prudente
# 4      Região Administrativa de Presidente Prudente
# ...
